# %% [markdown]
# <a href="https://colab.research.google.com/github/luqman3303/Data-Visualization-with-Pandas-Matplotlib-Seaborn-/blob/main/Student_Performance_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_excel('/content/drive/MyDrive/Linear regreesion/Student_Performance.xlsx')

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
print(df)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
x = df[['Hours Studied','Previous Scores','Extracurricular Activities','Sleep Hours','Sample Question Papers Practiced']]
y = df[['Performance Index']]

# %%
x
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced
# ...

# %%
from sklearn import model_selection
from sklearn import linear_model
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lr = linear_model.LinearRegression()

# Convert 'Extracurricular Activities' to numerical using one-hot encoding
x_train_encoded = pd.get_dummies(x_train, columns=['Extracurricular Activities'], drop_first=True)
x_test_encoded = pd.get_dummies(x_test, columns=['Extracurricular Activities'], drop_first=True)

lr.fit(x_train_encoded, y_train)
# Out:
# LinearRegression()

# %%
print(lr.score(x_test_encoded, y_test))
# Out:
# 0.9889832909573145

# %%
lr.predict(x_test_encoded)
# Out:
# array([[54.71185392],
#        [22.61551294],
#        [47.90314471],
#        ...,
#        [16.79341955],
#        [63.34327368],
#        [45.94262301]])

# %%
import pickle
with open('/content/drive/MyDrive/Linear regreesion/model.pkl', 'wb') as files:
  pickle.dump(lr, files)

# %%
with open('/content/drive/MyDrive/Linear regreesion/model.pkl', 'rb') as f:
  lr1 = pickle.load(f)

# %%
lr1.predict(x_test_encoded)
# Out:
# array([[54.71185392],
#        [22.61551294],
#        [47.90314471],
#        ...,
#        [16.79341955],
#        [63.34327368],
#        [45.94262301]])

# %%
import joblib
joblib.dump(lr, '/content/drive/MyDrive/Linear regreesion/model_joblib')
# Out:
# ['/content/drive/MyDrive/Linear regreesion/model_joblib']

# %%
joblib_lr = joblib.load('/content/drive/MyDrive/Linear regreesion/model_joblib')
